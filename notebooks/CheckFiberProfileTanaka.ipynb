# %%
from datetime import datetime
import os
import numpy as np

# %matplotlib notebook
# %matplotlib widget
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (9, 7)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:99% !important; }</style>"))
# Out:
# /tmp/ipykernel_74832/2243265436.py:10: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:99% !important; }</style>

# %%
from pfs.drp.stella.fiberProfileSet import FiberProfileSet

# %%
afwDisplay.setDefaultBackend("matplotlib")
afwDisplay.setDefaultMaskPlaneColor("BAD_FLAT", afwDisplay.CYAN)

# %% [markdown]
# ## Plot fiberProfiles
# FIXME: that as fiberProfiles not ingested into CALIB, loading them directly using ``readFits`` method. Ideally, use ``butler`` in all cases.

# %%
# butler=dafPersist.Butler('/work/drp/rerun/hassans/calib/fiberProfiles/')
# dataId = dict(visit=81979, arm="r", spectrograph=3)
# profiles = butler.get("fiberProfiles", dataId)
profiles=FiberProfileSet.readFits('/work/drp/rerun/hassans/tanaka/fiberProfiles/FIBERPROFILES/pfsFiberProfiles-2022-11-15-082113-r1.fits')

# %%
for fiberId in [3, 100, 300, 500, 600]:
    fig, _ = profiles[fiberId].plot()
    fig.suptitle(f'fiber {fiberId}')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tp = profiles[3].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
